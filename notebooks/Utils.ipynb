# %% [markdown]
# ## UTILS METHOD TEST

# %%
import sys
import torch
import numpy as np
import os 
from pathlib import Path

# add parent folder path
FOLDERPATH = '/home/aurel/Desktop/dev/hkust/DL/NeRFs-Arch' # modify this path as needed
sys.path.append(FOLDERPATH)

# device disponibility
USE_GPU = True
dtype = torch.float32

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('Using {} device'.format(device))
# Out:
# Using cpu device

# %% [markdown]
# #### Volume Rendering

# %% [markdown]
# Test : transmittance, pixel color

# %%
from utils.volume_rendering import get_color_from_ray_points, get_transmittances

densities = torch.tensor([0.1, 0.5, 0.2], requires_grad=True)
colors = torch.tensor([[0.8, 0.1, 0.1], [0.1, 0.8, 0.1], [0.1, 0.1, 0.8]], requires_grad=True)
pads = torch.tensor([1.0, 1.0, 1e10], requires_grad=False)

color_pixel = get_color_from_ray_points(densities, colors, pads)
transmittances = get_transmittances(densities,pads)

print("Pixel color: ", color_pixel)
print("Points transmittances: ",transmittances)
print("First point transmittance: ",transmittances[0])
# Out:
# Pixel color:  tensor([0.1666, 0.3492, 0.4842], grad_fn=<SumBackward1>)
# Points transmittances:  tensor([1.0000, 0.9048, 0.5488], grad_fn=<ExpBackward0>)
# First point transmittance:  tensor(1., grad_fn=<SelectBackward0>)
